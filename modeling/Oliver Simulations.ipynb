# %% [markdown]
# # Run Games

# %%
# imports
from random import randint
import numpy as np
import random
import datetime # for limiting calculation to wall clock time
import math
import copy
import matplotlib.pyplot as plt
import csv
import sys
import pandas as pd

import farmgame
from mcts import MCTS
from agents import RandomPolicy

# %%
# Game configuration
def configure_game():
    return farmgame.configure_game(
        layer="Items00", 
        resourceCond="even", 
        costCond="low", 
        visibilityCond="full", 
        redFirst=True
    )

# %%
policies = ["selfish", "altruistic", "collaborative"]

# %% [markdown]
# # Try to differentiate before and after helping

# %%
# Simulate a game for a given combination of policies and count helping actions
def simulate_game_with_helping(red_policy, purple_policy):
    print(f"Simulating a game: Red Policy = {red_policy}, Purple Policy = {purple_policy}")
    game = configure_game()
    red_agent = MCTS(time=2.0, nsims=5000000, C=1.0, max_moves=10, color="red", policy=red_policy)
    purple_agent = MCTS(time=2.0, nsims=5000000, C=1.0, max_moves=10, color="purple", policy=purple_policy)
    
    # Initialize agents with the starting state
    red_agent.update(game)
    purple_agent.update(game)
    
    state = game
    done = False
    turn_count = 0
    red_rewards = []
    purple_rewards = []
    
    # Helping action counters
    helping_actions = {
        "red": {"before": 0, "after": 0},
        "purple": {"before": 0, "after": 0}
    }
    
    # Flags for object pickup completion
    objects_picked_up = {"red": False, "purple": False}
    
    while not done:
        current_player = state.players[state.turn]["name"]
        
        if current_player == "red":
            action = red_agent.choose_action()
        else:
            action = purple_agent.choose_action()
        
        # Check if the action is helping
        transition = farmgame.Transition(state, action)
        is_helping = transition.is_helping()
        
        # Update helping action counters based on the flag
        if is_helping:
            if not objects_picked_up[current_player]:
                helping_actions[current_player]["before"] += 1
            else:
                helping_actions[current_player]["after"] += 1
        
        # Take the action
        state = state.take_action(action, inplace=True)
        red_agent.update(state)
        purple_agent.update(state)
        
        # Check if all objects are picked up for the current player
        if not objects_picked_up[current_player]:
            if state.all_objects_picked_up(current_player):  # Assuming this method exists in farmgame
                objects_picked_up[current_player] = True
        
        # Get rewards
        red_rwd, red_done = state.reward("red")
        purple_rwd, purple_done = state.reward("purple")
        done = red_done and purple_done
        
        # Log rewards
        red_rewards.append(red_rwd)
        purple_rewards.append(purple_rwd)
        
        turn_count += 1
    
    print(f"Game completed: Red Policy = {red_policy}, Purple Policy = {purple_policy}")
    print(f"Total Red Reward: {sum(red_rewards)}, Total Purple Reward: {sum(purple_rewards)}")
    print(f"Helping Actions Before - Red: {helping_actions['red']['before']}, Purple: {helping_actions['purple']['before']}")
    print(f"Helping Actions After - Red: {helping_actions['red']['after']}, Purple: {helping_actions['purple']['after']}")
    return red_rewards, purple_rewards, helping_actions

# Simulate games with helping actions
results_with_helping = []
for red_policy in policies:
    for purple_policy in policies:
        print(f"\nStarting simulations: Red Policy = {red_policy}, Purple Policy = {purple_policy}")
        for i in range(100):  # Simulate 10 games per combination
            print(f"  Simulation {i+1}: Red Policy = {red_policy}, Purple Policy = {purple_policy}")
            red_rewards, purple_rewards, helping_actions = simulate_game_with_helping(red_policy, purple_policy)
            results_with_helping.append({
                "Red Policy": red_policy,
                "Purple Policy": purple_policy,
                "Red Reward": sum(red_rewards),
                "Purple Reward": sum(purple_rewards),
                "Total Reward": sum(red_rewards) + sum(purple_rewards),
                "Red Helping Actions Before": helping_actions["red"]["before"],
                "Purple Helping Actions Before": helping_actions["purple"]["before"],
                "Red Helping Actions After": helping_actions["red"]["after"],
                "Purple Helping Actions After": helping_actions["purple"]["after"]
            })

# Convert the results to a DataFrame
results_with_helping_df = pd.DataFrame(results_with_helping)
# Out:
# Starting simulations: Red Policy = selfish, Purple Policy = selfish
#   Simulation 1: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 196, Total Purple Reward: 236
# Helping Actions Before - Red: 1, Purple: 0
# Helping Actions After - Red: 0, Purple: 1
#   Simulation 2: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 148, Total Purple Reward: 208
# Helping Actions Before - Red: 2, Purple: 2
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 3: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 236, Total Purple Reward: 208
# Helping Actions Before - Red: 0, Purple: 1
# Helping Actions After - Red: 1, Purple: 0
#   Simulation 4: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 244, Total Purple Reward: 200
# Helping Actions Before - Red: 3, Purple: 3
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 5: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 180, Total Purple Reward: 276
# Helping Actions Before - Red: 3, Purple: 4
# Helping Actions After - Red: 1, Purple: 0
#   Simulation 6: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 136, Total Purple Reward: 228
# Helping Actions Before - Red: 2, Purple: 2
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 7: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 276, Total Purple Reward: 280
# Helping Actions Before - Red: 4, Purple: 4
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 8: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 236, Total Purple Reward: 248
# Helping Actions Before - Red: 1, Purple: 2
# Helping Actions After - Red: 1, Purple: 0
#   Simulation 9: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 236, Total Purple Reward: 256
# Helping Actions Before - Red: 3, Purple: 2
# Helping Actions After - Red: 0, Purple: 1
#   Simulation 10: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 132, Total Purple Reward: 192
# Helping Actions Before - Red: 1, Purple: 1
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 11: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 216, Total Purple Reward: 224
# Helping Actions Before - Red: 2, Purple: 2
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 12: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 120, Total Purple Reward: 216
# Helping Actions Before - Red: 2, Purple: 1
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 13: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 144, Total Purple Reward: 232
# Helping Actions Before - Red: 0, Purple: 1
# Helping Actions After - Red: 2, Purple: 0
#   Simulation 14: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 156, Total Purple Reward: 240
# Helping Actions Before - Red: 2, Purple: 2
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 15: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 196, Total Purple Reward: 208
# Helping Actions Before - Red: 2, Purple: 2
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 16: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 196, Total Purple Reward: 244
# Helping Actions Before - Red: 2, Purple: 1
# Helping Actions After - Red: 0, Purple: 1
#   Simulation 17: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 228, Total Purple Reward: 216
# Helping Actions Before - Red: 2, Purple: 2
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 18: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 228, Total Purple Reward: 208
# Helping Actions Before - Red: 2, Purple: 2
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 19: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 164, Total Purple Reward: 200
# Helping Actions Before - Red: 2, Purple: 2
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 20: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 64, Total Purple Reward: 208
# Helping Actions Before - Red: 1, Purple: 2
# Helping Actions After - Red: 1, Purple: 0
#   Simulation 21: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 176, Total Purple Reward: 208
# Helping Actions Before - Red: 1, Purple: 1
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 22: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 236, Total Purple Reward: 224
# Helping Actions Before - Red: 0, Purple: 1
# Helping Actions After - Red: 1, Purple: 0
#   Simulation 23: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 268, Total Purple Reward: 296
# Helping Actions Before - Red: 4, Purple: 4
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 24: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 208, Total Purple Reward: 132
# Helping Actions Before - Red: 2, Purple: 2
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 25: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 228, Total Purple Reward: 204
# Helping Actions Before - Red: 1, Purple: 1
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 26: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 112, Total Purple Reward: 244
# Helping Actions Before - Red: 2, Purple: 2
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 27: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 224, Total Purple Reward: 148
# Helping Actions Before - Red: 1, Purple: 1
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 28: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 168, Total Purple Reward: 216
# Helping Actions Before - Red: 1, Purple: 1
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 29: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 180, Total Purple Reward: 236
# Helping Actions Before - Red: 1, Purple: 0
# Helping Actions After - Red: 0, Purple: 1
#   Simulation 30: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 172, Total Purple Reward: 228
# Helping Actions Before - Red: 0, Purple: 1
# Helping Actions After - Red: 1, Purple: 0
#   Simulation 31: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 140, Total Purple Reward: 200
# Helping Actions Before - Red: 1, Purple: 1
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 32: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 188, Total Purple Reward: 228
# Helping Actions Before - Red: 1, Purple: 1
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 33: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 268, Total Purple Reward: 280
# Helping Actions Before - Red: 0, Purple: 0
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 34: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 212, Total Purple Reward: 240
# Helping Actions Before - Red: 3, Purple: 3
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 35: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 236, Total Purple Reward: 204
# Helping Actions Before - Red: 1, Purple: 1
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 36: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 216, Total Purple Reward: 108
# Helping Actions Before - Red: 2, Purple: 2
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 37: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 188, Total Purple Reward: 204
# Helping Actions Before - Red: 2, Purple: 2
# Helping Actions After - Red: 0, Purple: 0
#   Simulation 38: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 244, Total Purple Reward: 232
# Helping Actions Before - Red: 0, Purple: 1
# Helping Actions After - Red: 1, Purple: 0
#   Simulation 39: Red Policy = selfish, Purple Policy = selfish
# Simulating a game: Red Policy = selfish, Purple Policy = selfish
# Game completed: Red Policy = selfish, Purple Policy = selfish
# Total Red Reward: 196, Total Purple Reward: 208
# Helping Actions Before - Red: 2, Purple: 1
# Helping Actions After - Red: 0, Purple: 1
#   Simulation
# 3          selfish        selfish         244            200           444
# 4          selfish        selfish         180            276           456
# ..             ...            ...         ...            ...           ...
# 895  collaborative  collaborative          88            224           312
# 896  collaborative  collaborative         212            160           372
# 897  collaborative  collaborative         220            188           408
# 898  collaborative  collaborative         196            208           404
# 899  collaborative  collaborative         244            248           492
#
#      Red Helping Actions Before  Purple Helping Actions Before  \
# 0                             1                              0
# 1                             2                              2
# 2                             0                              1
# 3                             3                              3
# 4                             3                              4
# ..                          ...                            ...
# 895                           1                              2
# 896                           2                              2
# 897                           3                              3
# 898                           1                              1
# 899                           1                              1
#
#      Red Helping Actions After  Purple Helping Actions After
# 0                            0                             1
# 1                            0                             0
# 2                            1                             0
# 3                            0                             0
# 4                            1                             0
# ..                         ...                           ...
# 895                          2                             0
# 896                          0                             0
# 897                          0                             0
# 898                          0                             0
# 899                          0                             0
#
# [900 rows x 9 columns]

# %%
results_with_helping_df.groupby(['Red Policy','Purple Policy']).mean()
# Out:
#                              Red Reward  Purple Reward  Total Reward  \
# Red Policy    Purple Policy
# altruistic    altruistic         190.04         208.60        398.64
#               collaborative      188.40         208.00        396.40
#               selfish            182.60         214.84        397.44
# collaborative altruistic         194.84         207.48        402.32
#               collaborative      191.28         209.44        400.72
#               selfish            188.68         206.84        395.52
# selfish       altruistic         201.32         201.12        402.44
#               collaborative      207.52         213.36        420.88
#               selfish            194.16         212.40        406.56
#
#                              Red Helping Actions Before  \
# Red Policy    Purple Policy
# altruistic    altruistic                           1.88
#               collaborative                        1.91
#               selfish                              1.80
# collaborative altruistic                           1.69
#               collaborative                        1.73
#               selfish                              1.67
# selfish       altruistic                           1.72
#               collaborative                        1.68
#               selfish                              1.73
#
#                              Purple Helping Actions Before  \
# Red Policy    Purple Policy
# altruistic    altruistic                              1.82
#               collaborative                           1.73
#               selfish                                 1.64
# collaborative altruistic                              1.65
#               collaborative                           1.71
#               selfish                                 1.51
# selfish       altruistic                              1.61
#               collaborative                           1.51
#               selfish                                 1.71
#
#                              Red Helping Actions After  \
# Red Policy    Purple Policy
# altruistic    altruistic                          0.10
#               collaborative                       0.06
#               selfish                             0.15
# collaborative altruistic                          0.14
#               collaborative                       0.15
#               selfish                             0.14
# selfish       altruistic                          0.06
#               collaborative                       0.11
#               selfish                             0.18
#
#                              Purple Helping Actions After
# Red Policy    Purple Policy
# altruistic    altruistic                             0.16
#               collaborative                          0.20
#               selfish                                0.22
# collaborative altruistic                             0.17
#               collaborative                          0.11
#               selfish                                0.21
# selfish       altruistic                             0.20
#               collaborative                          0.25
#               selfish                                0.14

# %%
results_with_helping_df.groupby('Red Policy')['Red Helping Actions Before'].mean()
# Out:
# Red Policy
# altruistic       1.863333
# collaborative    1.696667
# selfish          1.710000
# Name: Red Helping Actions Before, dtype: float64

# %%
# results_with_helping_df.to_csv('results_time_2_nsims_5000000_C_1_900_trials.csv')
