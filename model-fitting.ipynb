# %% [markdown]
# # Model fitting
# author: pam popp (pamop@nyu.edu)
# date: june 25, 2024

# %%
# imports
import numpy as np
import pandas as pd
import os

# display all columns of dataframes
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 60)

# # Prints out a game trial by trial in ascii
from utils import ascii_map as amap

# seed RNG
np.random.seed(0)

# %%
# Import data
# dir_path  = os.getcwd()
# change relative path depending on where you're running this script from
df = pd.read_csv('data/trialdf.csv')
df.head()

# to view the transcript of a single game from subject id and game number
# sesh = "4ISIiFA1J99JSc"
# game = 1
# amap.print_transcript(df, sesh, game)
# Out:
#                  subjid         session  trialNum  gameNum costCond  \
# 0     4ISIiFA1J99JScred  4ISIiFA1J99JSc         1        0     high
# 1  4ISIiFA1J99JScpurple  4ISIiFA1J99JSc         3        0     high
# 2     4ISIiFA1J99JScred  4ISIiFA1J99JSc         5        0     high
# 3  4ISIiFA1J99JScpurple  4ISIiFA1J99JSc         7        0     high
# 4     4ISIiFA1J99JScred  4ISIiFA1J99JSc         9        0     high
#
#   resourceCond visibilityCond  redFirst  counterbalance objectLayer  \
# 0         even           full      True            12.0     Items04
# 1         even           full      True            12.0     Items04
# 2         even           full      True            12.0     Items04
# 3         even           full      True            12.0     Items04
# 4         even           full      True            12.0     Items04
#
#       eventName  turnCount   agent        target  turnStartTimestamp  \
# 0  targetPicked          0     red      Tomato04       1678818021993
# ...
